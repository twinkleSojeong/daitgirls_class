# %% [markdown]
# <a href="https://colab.research.google.com/github/twinkleSojeong/daitgirls_class/blob/main/mcp_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B%20%EA%B5%AC%EC%B6%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone "https://github.com/FinanceData/marcap.git" marcap
# Out:
# Cloning into 'marcap'...
# remote: Enumerating objects: 1017, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 1017 (delta 102), reused 134 (delta 96), pack-reused 877
# Receiving objects: 100% (1017/1017), 2.12 GiB | 43.12 MiB/s, done.
# Resolving deltas: 100% (608/608), done.
# Checking out files: 100% (39/39), done.

# %%
#데이터 불러오기
from marcap import marcap_data as mcp

# %%
#2008년 이후부터 주식데이터 불러오기
df = marcap_data('2008-01-01','2021-09-03')
df
# Out:
#               Code     Name  Market  ...     Stocks  MarketId  Rank
# Date                                 ...
# 2008-01-02  005930     삼성전자   KOSPI  ...  147299337       STK     1
# 2008-01-02  005490    POSCO   KOSPI  ...   87186835       STK     2
# 2008-01-02  009540    현대중공업   KOSPI  ...   76000000       STK     3
# 2008-01-02  015760     한국전력   KOSPI  ...  641567712       STK     4
# 2008-01-02  060000     국민은행   KOSPI  ...  336379116       STK     5
# ...            ...      ...     ...  ...        ...       ...   ...
# 2021-08-20  215050  비엔디생활건강   KONEX  ...    2121666       KNX  2573
# 2021-08-20  093510   엔지브이아이   KONEX  ...    6020000       KNX  2575
# 2021-08-20  242350  피엔아이컴퍼니   KONEX  ...    4761520       KNX  2576
# 2021-08-20  267810       앙츠   KONEX  ...    1547000       KNX  2577
# 2021-08-20  038160      팍스넷  KOSDAQ  ...   12240376       KSQ  2580
#
# [6922489 rows x 17 columns]

# %%
import pandas as pd
pd.options.display.float_format =  '{:.1f}'.format

# %%
# !pip install -q finance-datareader

# %%
import FinanceDataReader as fdr

df_master = fdr.StockListing('KRX')
df_master.head(10)
# Out:
#    Symbol  Market  ...                       HomePage Region
# 0  060310  KOSDAQ  ...           http://www.3sref.com  서울특별시
# 1  095570   KOSPI  ...         http://www.ajnet.co.kr  서울특별시
# 2  006840   KOSPI  ...  http://www.aekyunggroup.co.kr  서울특별시
# 3  054620  KOSDAQ  ...   http://www.apsholdings.co.kr    경기도
# 4  265520  KOSDAQ  ...     http://www.apsystems.co.kr    경기도
# 5  211270  KOSDAQ  ...          http://www.apsi.co.kr  서울특별시
# 6  152100   KOSPI  ...                            NaN    NaN
# 7  295820   KOSPI  ...                            NaN    NaN
# 8  253150   KOSPI  ...                            NaN    NaN
# 9  253160   KOSPI  ...                            NaN    NaN
#
# [10 rows x 10 columns]

# %%
len(df_master)
# Out:
# 7104

# %%
df_master = df_master.dropna(subset=['Sector'])
df_master
# Out:
#       Symbol  Market  ...                       HomePage Region
# 0     060310  KOSDAQ  ...           http://www.3sref.com  서울특별시
# 1     095570   KOSPI  ...         http://www.ajnet.co.kr  서울특별시
# 2     006840   KOSPI  ...  http://www.aekyunggroup.co.kr  서울특별시
# 3     054620  KOSDAQ  ...   http://www.apsholdings.co.kr    경기도
# 4     265520  KOSDAQ  ...     http://www.apsystems.co.kr    경기도
# ...      ...     ...  ...                            ...    ...
# 7097  189980  KOSDAQ  ...        http://www.hyungkuk.com  서울특별시
# 7098  000540   KOSPI  ...     http://www.insurance.co.kr  서울특별시
# 7101  003280   KOSPI  ...         http://www.heung-a.com  서울특별시
# 7102  037440  KOSDAQ  ...          http://www.heerim.com  서울특별시
# 7103  238490  KOSDAQ  ...          http://www.hims.co.kr  인천광역시
#
# [2459 rows x 10 columns]

# %%
# 한글 폰트 설치와 폰트 캐시 재설정
# !apt-get install -y -qq fonts-nanum
# !rm -rf ~/.cache/matplotlib/*

# matplotlib 설정
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'NanumBarunGothic'
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.formatter.limits"] = -10000, 10000

plt.title('한글 테스트')
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 148492 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Text(0.5, 1.0, '한글 테스트')
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53580 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from marcap import marcap_data

# %%
df_marcap=marcap_data('2008-01-02','2021-09-03')

# %%
df_marcap[['Code','Name','Marcap']].reset_index()
# Out:
#               Date    Code     Name          Marcap
# 0       2008-01-02  005930     삼성전자  80130839328000
# 1       2008-01-02  005490    POSCO  48999001270000
# 2       2008-01-02  009540    현대중공업  33060000000000
# 3       2008-01-02  015760     한국전력  24796592068800
# 4       2008-01-02  060000     국민은행  22571038683600
# ...            ...     ...      ...             ...
# 6922484 2021-08-20  215050  비엔디생활건강      3362840610
# 6922485 2021-08-20  093510   엔지브이아이      3311000000
# 6922486 2021-08-20  242350  피엔아이컴퍼니      3185456880
# 6922487 2021-08-20  267810       앙츠      2072980000
# 6922488 2021-08-20  038160      팍스넷       771143688
#
# [6922489 rows x 4 columns]

# %%
df_master[['Symbol','Sector']]
# Out:
#       Symbol                    Sector
# 0     060310                  전자부품 제조업
# 1     095570           산업용 기계 및 장비 임대업
# 2     006840                    기타 금융업
# 3     054620                    기타 금융업
# 4     265520             특수 목적용 기계 제조업
# ...      ...                       ...
# 7097  189980           비알코올음료 및 얼음 제조업
# 7098  000540                       보험업
# 7101  003280                    해상 운송업
# 7102  037440  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7103  238490             특수 목적용 기계 제조업
#
# [2459 rows x 2 columns]

# %%
df_marcap
# Out:
#               Code     Name  Market  ...     Stocks  MarketId  Rank
# Date                                 ...
# 2008-01-02  005930     삼성전자   KOSPI  ...  147299337       STK     1
# 2008-01-02  005490    POSCO   KOSPI  ...   87186835       STK     2
# 2008-01-02  009540    현대중공업   KOSPI  ...   76000000       STK     3
# 2008-01-02  015760     한국전력   KOSPI  ...  641567712       STK     4
# 2008-01-02  060000     국민은행   KOSPI  ...  336379116       STK     5
# ...            ...      ...     ...  ...        ...       ...   ...
# 2021-08-20  215050  비엔디생활건강   KONEX  ...    2121666       KNX  2573
# 2021-08-20  093510   엔지브이아이   KONEX  ...    6020000       KNX  2575
# 2021-08-20  242350  피엔아이컴퍼니   KONEX  ...    4761520       KNX  2576
# 2021-08-20  267810       앙츠   KONEX  ...    1547000       KNX  2577
# 2021-08-20  038160      팍스넷  KOSDAQ  ...   12240376       KSQ  2580
#
# [6922489 rows x 17 columns]
